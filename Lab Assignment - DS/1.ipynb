# %%
# Program to Insert and Delete an Element at a Given Position in a List 
l = [10, 20, 30, 40, 50]
print("Original List:", l)

# Insert
pos = int(input("Enter position to insert: "))
element = int(input("Enter element: "))

if 0 <= pos <= len(l):
    l.insert(pos, element)
    print("After insertion:", l)
else:
    print("Invalid position")

# Delete
pos = int(input("Enter position to delete: "))

if 0 <= pos < len(l):
    print("Deleted element:", l.pop(pos))
    print("After deletion:", l)
else:
    print("Invalid position")
# Out:
# Original List: [10, 20, 30, 40, 50]
# After insertion: [22, 10, 20, 30, 40, 50]
# Deleted element: 10
# After deletion: [22, 20, 30, 40, 50]
